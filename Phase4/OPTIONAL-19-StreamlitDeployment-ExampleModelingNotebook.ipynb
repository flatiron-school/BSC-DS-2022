# %% [markdown]
# # Predicting Animal Adoptions

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 25)
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score, roc_auc_score, plot_confusion_matrix

# %% [markdown]
# ## Data Exploration and Merging

# %%
df_in = pd.read_csv('Austin_Animal_Center_Intakes_080422.csv', parse_dates=['DateTime'])
df_in = df_in.sort_values(by='DateTime')
df_in.head()
# Out:
#        Animal ID    Name            DateTime     MonthYear  \
# 73012    A521520    Nina 2013-10-01 07:51:00  October 2013
# 39003    A664235     NaN 2013-10-01 08:33:00  October 2013
# 2383     A664237     NaN 2013-10-01 08:33:00  October 2013
# 115994   A664236     NaN 2013-10-01 08:33:00  October 2013
# 117740   A664233  Stevie 2013-10-01 08:53:00  October 2013
#
#                         Found Location Intake Type Intake Condition  \
# 73012          Norht Ec in Austin (TX)       Stray           Normal
# 39003              Abia in Austin (TX)       Stray           Normal
# 2383               Abia in Austin (TX)       Stray           Normal
# 115994             Abia in Austin (TX)       Stray           Normal
# 117740  7405 Springtime in Austin (TX)       Stray          Injured
#
#        Animal Type Sex upon Intake Age upon Intake  \
# 73012          Dog   Spayed Female         7 years
# 39003          Cat         Unknown          1 week
# 2383           Cat         Unknown          1 week
# 115994         Cat         Unknown          1 week
# 117740         Dog   Intact Female         3 years
#
#                                Breed         Color
# 73012   Border Terrier/Border Collie     White/Tan
# 39003         Domestic Shorthair Mix  Orange/White
# 2383          Domestic Shorthair Mix  Orange/White
# 115994        Domestic Shorthair Mix  Orange/White
# 117740                  Pit Bull Mix    Blue/White

# %%
df_out = pd.read_csv('Austin_Animal_Center_Outcomes_080422.csv', parse_dates=['DateTime'])
df_out = df_out.sort_values(by='DateTime')
df_out.head()
# Out:
#        Animal ID     Name            DateTime MonthYear Date of Birth  \
# 60248    A659834  *Dudley 2013-10-01 09:31:00  Oct 2013    07/23/2013
# 49629    A664235      NaN 2013-10-01 10:39:00  Oct 2013    09/24/2013
# 108106   A664237      NaN 2013-10-01 10:44:00  Oct 2013    09/24/2013
# 91636    A664236      NaN 2013-10-01 10:44:00  Oct 2013    09/24/2013
# 11937    A664223     Moby 2013-10-01 11:03:00  Oct 2013    09/30/2009
#
#            Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# 60248          Adoption          Foster         Dog    Neutered Male
# 49629          Transfer         Partner         Cat          Unknown
# 108106         Transfer         Partner         Cat          Unknown
# 91636          Transfer         Partner         Cat          Unknown
# 11937   Return to Owner             NaN         Dog    Neutered Male
#
#        Age upon Outcome                   Breed         Color
# 60248          2 months  Labrador Retriever Mix         Black
# 49629            1 week  Domestic Shorthair Mix  Orange/White
# 108106           1 week  Domestic Shorthair Mix  Orange/White
# 91636            1 week  Domestic Shorthair Mix  Orange/White
# 11937           4 years             Bulldog Mix         White

# %%
# Create iterative counts for animals that have multiple intakes/outcomes
df_in['Intake Num'] = df_in.groupby('Animal ID', sort=False).cumcount()+1
df_out['Outcome Num'] = df_out.groupby('Animal ID', sort=False).cumcount()+1

# %%
# Checking a known repeat offender
df_in.loc[df_in['Animal ID'] == 'A721033'].tail(5)
# Out:
#        Animal ID     Name            DateTime       MonthYear  \
# 52717    A721033  Lil Bit 2019-04-26 10:28:00      April 2019
# 12761    A721033  Lil Bit 2019-05-20 10:18:00        May 2019
# 36609    A721033  Lil Bit 2019-08-05 10:52:00     August 2019
# 100219   A721033  Lil Bit 2019-09-16 14:06:00  September 2019
# 27818    A721033  Lil Bit 2019-10-05 12:31:00    October 2019
#
#                                         Found Location    Intake Type  \
# 52717            South 1St And Stassney in Austin (TX)  Public Assist
# 12761   1819 South Pleasant Valley Road in Austin (TX)  Public Assist
# 36609                 Burton And Oltorf in Austin (TX)  Public Assist
# 100219      Justin Lane And North Lamar in Austin (TX)  Public Assist
# 27818            1135 Airport Boulevard in Austin (TX)  Public Assist
#
#        Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 52717            Normal         Dog   Neutered Male         3 years
# 12761            Normal         Dog   Neutered Male         4 years
# 36609            Normal         Dog   Neutered Male         4 years
# 100219           Normal         Dog   Neutered Male         4 years
# 27818            Normal         Dog   Neutered Male         4 years
#
#                   Breed                   Color  Intake Num
# 52717   Rat Terrier Mix  Tricolor/Brown Brindle          29
# 12761   Rat Terrier Mix  Tricolor/Brown Brindle          30
# 36609   Rat Terrier Mix  Tricolor/Brown Brindle          31
# 100219  Rat Terrier Mix  Tricolor/Brown Brindle          32
# 27818   Rat Terrier Mix  Tricolor/Brown Brindle          33

# %%
df_out.loc[df_out['Animal ID'] == 'A721033'].tail(5)
# Out:
#       Animal ID     Name            DateTime MonthYear Date of Birth  \
# 28529   A721033  Lil Bit 2019-05-04 08:37:00  May 2019    05/20/2015
# 18006   A721033  Lil Bit 2019-05-21 14:42:00  May 2019    05/20/2015
# 4520    A721033  Lil Bit 2019-08-10 11:56:00  Aug 2019    05/20/2015
# 62287   A721033  Lil Bit 2019-09-19 11:02:00  Sep 2019    05/20/2015
# 66979   A721033  Lil Bit 2019-10-20 11:35:00  Oct 2019    05/20/2015
#
#           Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# 28529  Return to Owner             NaN         Dog    Neutered Male
# 18006  Return to Owner             NaN         Dog    Neutered Male
# 4520   Return to Owner             NaN         Dog    Neutered Male
# 62287  Return to Owner             NaN         Dog    Neutered Male
# 66979        Rto-Adopt             NaN         Dog    Neutered Male
#
#       Age upon Outcome            Breed                   Color  Outcome Num
# 28529          3 years  Rat Terrier Mix  Tricolor/Brown Brindle           29
# 18006          4 years  Rat Terrier Mix  Tricolor/Brown Brindle           30
# 4520           4 years  Rat Terrier Mix  Tricolor/Brown Brindle           31
# 62287          4 years  Rat Terrier Mix  Tricolor/Brown Brindle           32
# 66979          4 years  Rat Terrier Mix  Tricolor/Brown Brindle           33

# %%
df = df_in.merge(df_out, 
                 left_on=['Animal ID', 'Intake Num'], 
                 right_on=['Animal ID', 'Outcome Num'],
                 how='inner',
                 suffixes=("_in", "_out"))

# %%
df.head()
# Out:
#   Animal ID Name_in         DateTime_in  MonthYear_in  \
# 0   A521520    Nina 2013-10-01 07:51:00  October 2013
# 1   A664235     NaN 2013-10-01 08:33:00  October 2013
# 2   A664237     NaN 2013-10-01 08:33:00  October 2013
# 3   A664236     NaN 2013-10-01 08:33:00  October 2013
# 4   A664233  Stevie 2013-10-01 08:53:00  October 2013
#
#                    Found Location Intake Type Intake Condition Animal Type_in  \
# 0         Norht Ec in Austin (TX)       Stray           Normal            Dog
# 1             Abia in Austin (TX)       Stray           Normal            Cat
# 2             Abia in Austin (TX)       Stray           Normal            Cat
# 3             Abia in Austin (TX)       Stray           Normal            Cat
# 4  7405 Springtime in Austin (TX)       Stray          Injured            Dog
#
#   Sex upon Intake Age upon Intake                      Breed_in      Color_in  \
# 0   Spayed Female         7 years  Border Terrier/Border Collie     White/Tan
# 1         Unknown          1 week        Domestic Shorthair Mix  Orange/White
# 2         Unknown          1 week        Domestic Shorthair Mix  Orange/White
# 3         Unknown          1 week        Domestic Shorthair Mix  Orange/White
# 4   Intact Female         3 years                  Pit Bull Mix    Blue/White
#
#    Intake Num Name_out        DateTime_out MonthYear_out Date of Birth  \
# 0           1     Nina 2013-10-01 15:39:00      Oct 2013    09/07/2006
# 1           1      NaN 2013-10-01 10:39:00      Oct 2013    09/24/2013
# 2           1      NaN 2013-10-01 10:44:00      Oct 2013    09/24/2013
# 3           1      NaN 2013-10-01 10:44:00      Oct 2013    09/24/2013
# 4           1   Stevie 2013-10-01 15:33:00      Oct 2013    09/30/2010
#
#       Outcome Type Outcome Subtype Animal Type_out Sex upon Outcome  \
# 0  Return to Owner             NaN             Dog    Spayed Female
# 1         Transfer         Partner             Cat          Unknown
# 2         Transfer         Partner             Cat          Unknown
# 3         Transfer         Partner             Cat          Unknown
# 4       Euthanasia       Suffering             Dog    Intact Female
#
#   Age upon Outcome                     Breed_out     Color_out  Outcome Num
# 0          7 years  Border Terrier/Border Collie     White/Tan            1
# 1           1 week        Domestic Shorthair Mix  Orange/White            1
# 2           1 week        Domestic Shorthair Mix  Orange/White            1
# 3           1 week        Domestic Shorthair Mix  Orange/White            1
# 4          3 years                  Pit Bull Mix    Blue/White            1

# %%
df.columns
# Out:
# Index(['Animal ID', 'Name_in', 'DateTime_in', 'MonthYear_in', 'Found Location',
#        'Intake Type', 'Intake Condition', 'Animal Type_in', 'Sex upon Intake',
#        'Age upon Intake', 'Breed_in', 'Color_in', 'Intake Num', 'Name_out',
#        'DateTime_out', 'MonthYear_out', 'Date of Birth', 'Outcome Type',
#        'Outcome Subtype', 'Animal Type_out', 'Sex upon Outcome',
#        'Age upon Outcome', 'Breed_out', 'Color_out', 'Outcome Num'],
#       dtype='object')

# %%
# Exploring rows where the simple iterative count didn't work 
# Aka the outcome date was before the intake date
dirty = df.loc[df['DateTime_in'] > df['DateTime_out']]

# %%
dirty.shape
# Out:
# (725, 25)

# %%
dirty = dirty[['Animal ID', 'DateTime_in', 'Intake Num']]

# %%
# Going to add 1 to intake num, then try to merge again
dirty['Intake Num'] += 1

# %%
dirty.head()
# Out:
#     Animal ID         DateTime_in  Intake Num
# 203   A663004 2013-10-04 14:11:00           2
# 288   A663572 2013-10-06 11:00:00           2
# 426   A663722 2013-10-09 12:11:00           2
# 427   A663723 2013-10-09 12:11:00           2
# 609   A663667 2013-10-12 17:17:00           2

# %%
df_in_clean = df_in.copy()

# %%
df_in_clean = df_in_clean.merge(dirty,
                                left_on=['Animal ID', 'DateTime'], 
                                right_on=['Animal ID', 'DateTime_in'], 
                                how='left',
                                suffixes=('_dirty', '_clean'))

# %%
df_in_clean = df_in_clean.drop(columns=['DateTime_in'])
df_in_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 142796 entries, 0 to 142795
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Animal ID         142796 non-null  object
#  1   Name              100856 non-null  object
#  2   DateTime          142796 non-null  datetime64[ns]
#  3   MonthYear         142796 non-null  object
#  4   Found Location    142796 non-null  object
#  5   Intake Type       142796 non-null  object
#  6   Intake Condition  142796 non-null  object
#  7   Animal Type       142796 non-null  object
#  8   Sex upon Intake   142795 non-null  object
#  9   Age upon Intake   142796 non-null  object
#  10  Breed             142796 non-null  object
#  11  Color             142796 non-null  object
#  12  Intake Num_dirty  142796 non-null  int64
#  13  Intake Num_clean  726 non-null     float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(11)
# memory usage: 16.3+ MB

# %%
df_in_clean['Intake Num'] = np.where(~df_in_clean['Intake Num_clean'].isna(),
                                     df_in_clean['Intake Num_clean'],
                                     df_in_clean['Intake Num_dirty'])

# %%
df_in_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 142796 entries, 0 to 142795
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Animal ID         142796 non-null  object
#  1   Name              100856 non-null  object
#  2   DateTime          142796 non-null  datetime64[ns]
#  3   MonthYear         142796 non-null  object
#  4   Found Location    142796 non-null  object
#  5   Intake Type       142796 non-null  object
#  6   Intake Condition  142796 non-null  object
#  7   Animal Type       142796 non-null  object
#  8   Sex upon Intake   142795 non-null  object
#  9   Age upon Intake   142796 non-null  object
#  10  Breed             142796 non-null  object
#  11  Color             142796 non-null  object
#  12  Intake Num_dirty  142796 non-null  int64
#  13  Intake Num_clean  726 non-null     float64
#  14  Intake Num        142796 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(11)
# memory usage: 17.4+ MB

# %%
df = df_in_clean.merge(df_out, 
                       left_on=['Animal ID', 'Intake Num'], 
                       right_on=['Animal ID', 'Outcome Num'],
                       how='inner',
                       suffixes=("_in", "_out"))

# %%
df.columns
# Out:
# Index(['Animal ID', 'Name_in', 'DateTime_in', 'MonthYear_in', 'Found Location',
#        'Intake Type', 'Intake Condition', 'Animal Type_in', 'Sex upon Intake',
#        'Age upon Intake', 'Breed_in', 'Color_in', 'Intake Num_dirty',
#        'Intake Num_clean', 'Intake Num', 'Name_out', 'DateTime_out',
#        'MonthYear_out', 'Date of Birth', 'Outcome Type', 'Outcome Subtype',
#        'Animal Type_out', 'Sex upon Outcome', 'Age upon Outcome', 'Breed_out',
#        'Color_out', 'Outcome Num'],
#       dtype='object')

# %%
# Re-checking for that kind of dirty data...
df.loc[df['DateTime_in'] > df['DateTime_out']] # yassssss
# Out:
# Empty DataFrame
# Columns: [Animal ID, Name_in, DateTime_in, MonthYear_in, Found Location, Intake Type, Intake Condition, Animal Type_in, Sex upon Intake, Age upon Intake, Breed_in, Color_in, Intake Num_dirty, Intake Num_clean, Intake Num, Name_out, DateTime_out, MonthYear_out, Date of Birth, Outcome Type, Outcome Subtype, Animal Type_out, Sex upon Outcome, Age upon Outcome, Breed_out, Color_out, Outcome Num]
# Index: []
#
# [0 rows x 27 columns]

# %% [markdown]
# ## Data Exploration and Feature Engineering

# %%
df.head().T
# Out:
#                                              0                       1  \
# Animal ID                              A521520                 A664235
# Name_in                                   Nina                     NaN
# DateTime_in                2013-10-01 07:51:00     2013-10-01 08:33:00
# MonthYear_in                      October 2013            October 2013
# Found Location         Norht Ec in Austin (TX)     Abia in Austin (TX)
# Intake Type                              Stray                   Stray
# Intake Condition                        Normal                  Normal
# Animal Type_in                             Dog                     Cat
# Sex upon Intake                  Spayed Female                 Unknown
# Age upon Intake                        7 years                  1 week
# Breed_in          Border Terrier/Border Collie  Domestic Shorthair Mix
# Color_in                             White/Tan            Orange/White
# Intake Num_dirty                             1                       1
# Intake Num_clean                           NaN                     NaN
# Intake Num                                   1                       1
# Name_out                                  Nina                     NaN
# DateTime_out               2013-10-01 15:39:00     2013-10-01 10:39:00
# MonthYear_out                         Oct 2013                Oct 2013
# Date of Birth                       09/07/2006              09/24/2013
# Outcome Type                   Return to Owner                Transfer
# Outcome Subtype                            NaN                 Partner
# Animal Type_out                            Dog                     Cat
# Sex upon Outcome                 Spayed Female                 Unknown
# Age upon Outcome                       7 years                  1 week
# Breed_out         Border Terrier/Border Collie  Domestic Shorthair Mix
# Color_out                            White/Tan            Orange/White
# Outcome Num                                  1                       1
#
#                                        2                       3  \
# Animal ID                        A664237                 A664236
# Name_in                              NaN                     NaN
# DateTime_in          2013-10-01 08:33:00     2013-10-01 08:33:00
# MonthYear_in                October 2013            October 2013
# Found Location       Abia in Austin (TX)     Abia in Austin (TX)
# Intake Type                        Stray                   Stray
# Intake Condition                  Normal                  Normal
# Animal Type_in                       Cat                     Cat
# Sex upon Intake                  Unknown                 Unknown
# Age upon Intake                   1 week                  1 week
# Breed_in          Domestic Shorthair Mix  Domestic Shorthair Mix
# Color_in                    Orange/White            Orange/White
# Intake Num_dirty                       1                       1
# Intake Num_clean                     NaN                     NaN
# Intake Num                             1                       1
# Name_out                             NaN                     NaN
# DateTime_out         2013-10-01 10:44:00     2013-10-01 10:44:00
# MonthYear_out                   Oct 2013                Oct 2013
# Date of Birth                 09/24/2013              09/24/2013
# Outcome Type                    Transfer                Transfer
# Outcome Subtype                  Partner                 Partner
# Animal Type_out                      Cat                     Cat
# Sex upon Outcome                 Unknown                 Unknown
# Age upon Outcome                  1 week                  1 week
# Breed_out         Domestic Shorthair Mix  Domestic Shorthair Mix
# Color_out                   Orange/White            Orange/White
# Outcome Num                            1                       1
#
#                                                4
# Animal ID                                A664233
# Name_in                                   Stevie
# DateTime_in                  2013-10-01 08:53:00
# MonthYear_in                        October 2013
# Found Location    7405 Springtime in Austin (TX)
# Intake Type                                Stray
# Intake Condition                         Injured
# Animal Type_in                               Dog
# Sex upon Intake                    Intact Female
# Age upon Intake                          3 years
# Breed_in                            Pit Bull Mix
# Color_in                              Blue/White
# Intake Num_dirty                               1
# Intake Num_clean                             NaN
# Intake Num                                     1
# Name_out                                  Stevie
# DateTime_out                 2013-10-01 15:33:00
# MonthYear_out                           Oct 2013
# Date of Birth                         09/30/2010
# Outcome Type                          Euthanasia
# Outcome Subtype                        Suffering
# Animal Type_out                              Dog
# Sex upon Outcome                   Intact Female
# Age upon Outcome                         3 years
# Breed_out                           Pit Bull Mix
# Color_out                             Blue/White
# Outcome Num                                    1

# %%
# Segmenting down to mostly intake columns that I'll explore
data = df[['Animal ID', 'DateTime_in', 'Intake Type', 'Intake Condition', 
           'Animal Type_in', 'Sex upon Intake', 'Age upon Intake', 'Breed_in', 
           'Color_in', 'Intake Num', 'DateTime_out', 'Date of Birth', 'Outcome Type']]

# %%
data.head()
# Out:
#   Animal ID         DateTime_in Intake Type Intake Condition Animal Type_in  \
# 0   A521520 2013-10-01 07:51:00       Stray           Normal            Dog
# 1   A664235 2013-10-01 08:33:00       Stray           Normal            Cat
# 2   A664237 2013-10-01 08:33:00       Stray           Normal            Cat
# 3   A664236 2013-10-01 08:33:00       Stray           Normal            Cat
# 4   A664233 2013-10-01 08:53:00       Stray          Injured            Dog
#
#   Sex upon Intake Age upon Intake                      Breed_in      Color_in  \
# 0   Spayed Female         7 years  Border Terrier/Border Collie     White/Tan
# 1         Unknown          1 week        Domestic Shorthair Mix  Orange/White
# 2         Unknown          1 week        Domestic Shorthair Mix  Orange/White
# 3         Unknown          1 week        Domestic Shorthair Mix  Orange/White
# 4   Intact Female         3 years                  Pit Bull Mix    Blue/White
#
#    Intake Num        DateTime_out Date of Birth     Outcome Type
# 0         1.0 2013-10-01 15:39:00    09/07/2006  Return to Owner
# 1         1.0 2013-10-01 10:39:00    09/24/2013         Transfer
# 2         1.0 2013-10-01 10:44:00    09/24/2013         Transfer
# 3         1.0 2013-10-01 10:44:00    09/24/2013         Transfer
# 4         1.0 2013-10-01 15:33:00    09/30/2010       Euthanasia

# %%
data['Outcome Type'].value_counts()
# Out:
# Adoption           64812
# Transfer           40798
# Return to Owner    23216
# Euthanasia          9242
# Died                1303
# Rto-Adopt            921
# Disposal             630
# Missing               70
# Relocate              23
# Stolen                 2
# Lost                   1
# Name: Outcome Type, dtype: int64

# %%
# Excluding animals that were returned to owner in some way
data = data.loc[(data['Outcome Type'] != 'Return to Owner') & (data['Outcome Type'] != 'Rto-Adopt')]

# %%
data.head()
# Out:
#   Animal ID         DateTime_in Intake Type Intake Condition Animal Type_in  \
# 1   A664235 2013-10-01 08:33:00       Stray           Normal            Cat
# 2   A664237 2013-10-01 08:33:00       Stray           Normal            Cat
# 3   A664236 2013-10-01 08:33:00       Stray           Normal            Cat
# 4   A664233 2013-10-01 08:53:00       Stray          Injured            Dog
# 5   A664238 2013-10-01 09:33:00       Stray           Normal            Cat
#
#   Sex upon Intake Age upon Intake                Breed_in      Color_in  \
# 1         Unknown          1 week  Domestic Shorthair Mix  Orange/White
# 2         Unknown          1 week  Domestic Shorthair Mix  Orange/White
# 3         Unknown          1 week  Domestic Shorthair Mix  Orange/White
# 4   Intact Female         3 years            Pit Bull Mix    Blue/White
# 5         Unknown        4 months  American Shorthair Mix   Black/White
#
#    Intake Num        DateTime_out Date of Birth Outcome Type
# 1         1.0 2013-10-01 10:39:00    09/24/2013     Transfer
# 2         1.0 2013-10-01 10:44:00    09/24/2013     Transfer
# 3         1.0 2013-10-01 10:44:00    09/24/2013     Transfer
# 4         1.0 2013-10-01 15:33:00    09/30/2010   Euthanasia
# 5         1.0 2013-10-01 16:47:00    06/01/2013   Euthanasia

# %%
data['Outcome Type'].value_counts(normalize=True)
# Out:
# Adoption      0.554513
# Transfer      0.349056
# Euthanasia    0.079072
# Died          0.011148
# Disposal      0.005390
# Missing       0.000599
# Relocate      0.000197
# Stolen        0.000017
# Lost          0.000009
# Name: Outcome Type, dtype: float64

# %%
# Creating our target column
data['Adopted'] = np.where(data['Outcome Type'] == 'Adoption', 1, 0)

# %%
data['Adopted'].value_counts(normalize=True)
# Out:
# 1    0.554418
# 0    0.445582
# Name: Adopted, dtype: float64

# %%
data.head()
# Out:
#   Animal ID         DateTime_in Intake Type Intake Condition Animal Type_in  \
# 1   A664235 2013-10-01 08:33:00       Stray           Normal            Cat
# 2   A664237 2013-10-01 08:33:00       Stray           Normal            Cat
# 3   A664236 2013-10-01 08:33:00       Stray           Normal            Cat
# 4   A664233 2013-10-01 08:53:00       Stray          Injured            Dog
# 5   A664238 2013-10-01 09:33:00       Stray           Normal            Cat
#
#   Sex upon Intake Age upon Intake                Breed_in      Color_in  \
# 1         Unknown          1 week  Domestic Shorthair Mix  Orange/White
# 2         Unknown          1 week  Domestic Shorthair Mix  Orange/White
# 3         Unknown          1 week  Domestic Shorthair Mix  Orange/White
# 4   Intact Female         3 years            Pit Bull Mix    Blue/White
# 5         Unknown        4 months  American Shorthair Mix   Black/White
#
#    Intake Num        DateTime_out Date of Birth Outcome Type  Adopted
# 1         1.0 2013-10-01 10:39:00    09/24/2013     Transfer        0
# 2         1.0 2013-10-01 10:44:00    09/24/2013     Transfer        0
# 3         1.0 2013-10-01 10:44:00    09/24/2013     Transfer        0
# 4         1.0 2013-10-01 15:33:00    09/30/2010   Euthanasia        0
# 5         1.0 2013-10-01 16:47:00    06/01/2013   Euthanasia        0

# %%
data.describe(include='O')
# Out:
#        Animal ID Intake Type Intake Condition Animal Type_in Sex upon Intake  \
# count     116901      116901           116901         116901          116901
# unique    108599           6               15              5               5
# top      A754989       Stray           Normal            Dog     Intact Male
# freq           8       79889            99023          57917           40451
#
#        Age upon Intake                Breed_in     Color_in Date of Birth  \
# count           116901                  116901       116901        116901
# unique              50                    2482          580          7064
# top             1 year  Domestic Shorthair Mix  Black/White    04/21/2014
# freq             19862                   30822        12185           111
#
#        Outcome Type
# count        116881
# unique            9
# top        Adoption
# freq          64812

# %%
obj_cols = [c for c in data.columns if data[c].dtype == 'O']

# %%
for col in obj_cols[1:]:
    print(col)
    print(data[col].value_counts())
    print("*"*20)
# Out:
# Intake Type
# Stray                 79889
# Owner Surrender       27653
# Wildlife               5459
# Public Assist          2911
# Abandoned               735
# Euthanasia Request      254
# Name: Intake Type, dtype: int64
# ********************
# Intake Condition
# Normal        99023
# Injured        6985
# Sick           5759
# Nursing        3770
# Neonatal        427
# Aged            279
# Other           241
# Medical         156
# Feral           119
# Pregnant         96
# Behavior         36
# Space             4
# Med Attn          3
# Med Urgent        2
# Agonal            1
# Name: Intake Condition, dtype: int64
# ********************
# Animal Type_in
# Dog          57917
# Cat          50889
# Other         7449
# Bird           626
# Livestock       20
# Name: Animal Type_in, dtype: int64
# ********************
# Sex upon Intake
# Intact Male      40451
# Intact Female    40315
# Neutered Male    13226
# Spayed Female    12014
# Unknown          10895
# Name: Sex upon Intake, dtype: int64
# ********************
# Age upon Intake
# 1 year       19862
# 2 years      17149
# 1 month      13831
# 2 months      7780
# 3 years       5568
# 4 weeks       5109
# 3 weeks       4050
# 3 months      3619
# 4 months      3443
# 5 months      3198
# 4 years       3162
# 5 years       2853
# 2 weeks       2841
# 6 months      2454
# 6 years       1833
# 7 months      1827
# 9 months      1763
# 8 years       1592
# 7 years       1560
# 8 months      1417
# 10 years      1261
# 1 week        1122
# 1 weeks       1010
# 10 months      922
# 0 years        891
# 9 years        879
# 1 day          732
# 3 days         692
# 11 months      632
# 12 years       606
# 2 days         567
# 11 years       439
# 6 days         402
# 5 weeks        357
# 13 years       349
# 4 days         337
# 14 years       240
# 15 years       202
# 5 days         187
# 16 years        72
# 17 years        40
# 18 years        23
# 20 years        11
# 19 years        10
# 22 years         2
# 30 years         1
# 23 years         1
# 25 years         1
# 21 years         1
# -1 years         1
# Name: Age upon Intake, dtype: int64
# ********************
# Breed_in
# Domestic Shorthair Mix                        30822
# Domestic Shorthair                            11171
# Pit Bull Mix                                   5973
# Labrador Retriever Mix                         5838
# Chihuahua Shorthair Mix                        4990
#                                               ...
# American Staffordshire Terrier/Plott Hound        1
# American Staffordshire Terrier/Rottweiler         1
# Standard Schnauzer/Labrador Retriever             1
# Australian Shepherd/Dachshund                     1
# Black Mouth Cur/Staffordshire                     1
# Name: Breed_in, Length: 2482, dtype: int64
# ********************
# Color_in
# Black/White              12185
# Black                    10280
# Brown Tabby               7783
# Brown                     5155
# Brown Tabby/White         3970
#                          ...
# Black Tabby/Brown            1
# Blue/Gold                    1
# Blue Tabby/Buff              1
# Orange/Blue                  1
# Lynx Point/Gray Tabby        1
# Name: Color_in, Length: 580, dtype: int64
# ********************
# Date of Birth
# 04/21/2014    111
# 05/01/2016    107
# 05/05/2014    107
# 04/16/2018    103
# 09/01/2015    103
#              ...
# 09/18/2007      1
# 02/25/2003      1
# 01/17/2002      1
# 08/15/2004      1
# 10/17/2009      1
# Name: Date of Birth, Length: 7064, dtype: int64
# ********************
# Outcome Type
# Adoption      64812
# Transfer      40798
# Euthanasia     9242
# Died           1303
# Disposal        630
# Missing          70
# Relocate         23
# Stolen            2
# Lost              1
# Name: Outcome Type, dtype: int64
# ********************

# %%
# Creating Age in Days from date of birth
data['Age in Days'] = (pd.Timestamp.today().date() - pd.to_datetime(data['Date of Birth']).dt.date).dt.days

# %%
# Creating an indicator for black animals (notoriously under-adopted)
data['Color_black'] = data['Color_in'].str.lower().str.contains('black')

# %%
# Creating a 'fixed' col for animals that come in fixed
data['Fixed'] = np.where(
    (data['Sex upon Intake'] == 'Neutered Male') | (data['Sex upon Intake'] == 'Spayed Female'), 1, 0)

# %%
# Going to only look at dogs and cats
data['Animal Type_in'] = data['Animal Type_in'].replace({'Bird': 'Other', 'Livestock': 'Other'})

# %%
data['Type_Cat'] = data['Animal Type_in'] == 'Cat'
data['Type_Dog'] = data['Animal Type_in'] == 'Dog'

# %%
# Finding not-normal intake conditions
data['Intake Condition_Not Normal'] = data['Intake Condition'] != 'Normal'

# %%
# Creating a 'female' indicator
data['Female'] = data['Sex upon Intake'].str.contains("Female")

# %%
# Simplifying the age in days column to extract animals < 1yo
data['Young'] = data['Age in Days'] < 365

# %%
data.head()
# Out:
#   Animal ID         DateTime_in Intake Type Intake Condition Animal Type_in  \
# 1   A664235 2013-10-01 08:33:00       Stray           Normal            Cat
# 2   A664237 2013-10-01 08:33:00       Stray           Normal            Cat
# 3   A664236 2013-10-01 08:33:00       Stray           Normal            Cat
# 4   A664233 2013-10-01 08:53:00       Stray          Injured            Dog
# 5   A664238 2013-10-01 09:33:00       Stray           Normal            Cat
#
#   Sex upon Intake Age upon Intake                Breed_in      Color_in  \
# 1         Unknown          1 week  Domestic Shorthair Mix  Orange/White
# 2         Unknown          1 week  Domestic Shorthair Mix  Orange/White
# 3         Unknown          1 week  Domestic Shorthair Mix  Orange/White
# 4   Intact Female         3 years            Pit Bull Mix    Blue/White
# 5         Unknown        4 months  American Shorthair Mix   Black/White
#
#    Intake Num        DateTime_out Date of Birth Outcome Type  Adopted  \
# 1         1.0 2013-10-01 10:39:00    09/24/2013     Transfer        0
# 2         1.0 2013-10-01 10:44:00    09/24/2013     Transfer        0
# 3         1.0 2013-10-01 10:44:00    09/24/2013     Transfer        0
# 4         1.0 2013-10-01 15:33:00    09/30/2010   Euthanasia        0
# 5         1.0 2013-10-01 16:47:00    06/01/2013   Euthanasia        0
#
#    Age in Days  Color_black  Fixed  Type_Cat  Type_Dog  \
# 1         3237        False      0      True     False
# 2         3237        False      0      True     False
# 3         3237        False      0      True     False
# 4         4327        False      0     False      True
# 5         3352         True      0      True     False
#
#    Intake Condition_Not Normal  Female  Young
# 1                        False   False  False
# 2                        False   False  False
# 3                        False   False  False
# 4                         True    True  False
# 5                        False   False  False

# %% [markdown]
# # Modeling

# %%
# Defining our used calls - all indicator boolean columns!
used_cols = ['Color_black', 'Fixed', 'Type_Cat', 'Type_Dog', 
             'Intake Condition_Not Normal', 'Female', 'Young']

# %%
X = data[used_cols]
y = data['Adopted']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=84)

# %% [markdown]
# ## Model-Less Baseline

# %%
y_train.value_counts(normalize=True)
# Out:
# 1    0.554548
# 0    0.445452
# Name: Adopted, dtype: float64

# %% [markdown]
# ## Logistic Regression

# %%
logreg = LogisticRegression()

logreg.fit(X_train, y_train)

logreg.score(X_train, y_train)
# Out:
# 0.6491246079270031

# %%
test_preds = logreg.predict(X_test)
test_probas = logreg.predict_proba(X_test)[:,1]

print(f"Test Acc: {logreg.score(X_test, y_test)}")
print(f"Test F1: {f1_score(y_test, test_preds)}")
print(f"Test ROCAUC: {roc_auc_score(y_test, test_probas)}")

plot_confusion_matrix(logreg, X_test, y_test);
# Out:
# Test Acc: 0.644186683090399
# Test F1: 0.7383701914609907
# Test ROCAUC: 0.6757230851009308

# %% [markdown]
# ## Decision Tree

# %%
tree = DecisionTreeClassifier(max_depth=5)

tree.fit(X_train, y_train)

tree.score(X_train, y_train)
# Out:
# 0.6505959509552324

# %%
test_preds = tree.predict(X_test)
test_probas = tree.predict_proba(X_test)[:,1]

print(f"Test Acc: {tree.score(X_test, y_test)}")
print(f"Test F1: {f1_score(y_test, test_preds)}")
print(f"Test ROCAUC: {roc_auc_score(y_test, test_probas)}")

plot_confusion_matrix(tree, X_test, y_test);
# Out:
# Test Acc: 0.6460685690823239
# Test F1: 0.7406738868832733
# Test ROCAUC: 0.6775431387338435

# %% [markdown]
# ## Random Forest

# %%
rf = RandomForestClassifier(max_depth=5)

rf.fit(X_train, y_train)

rf.score(X_train, y_train)
# Out:
# 0.6554205873966353

# %%
test_preds = rf.predict(X_test)
test_probas = rf.predict_proba(X_test)[:,1]

print(f"Test Acc: {rf.score(X_test, y_test)}")
print(f"Test F1: {f1_score(y_test, test_preds)}")
print(f"Test ROCAUC: {roc_auc_score(y_test, test_probas)}")

plot_confusion_matrix(rf, X_test, y_test);
# Out:
# Test Acc: 0.6525696297817012
# Test F1: 0.713422894558591
# Test ROCAUC: 0.6792337493464949

# %% [markdown]
# # Save Model for Deployment

# %%
import pickle

# %%
# Test that out, too!
