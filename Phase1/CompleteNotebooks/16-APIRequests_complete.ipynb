# %% [markdown]
# # APIs - Gathering Data Using Requests

# %% [markdown]
# ## The Many Use Cases For APIs
#
# APIs can be used for many things - much more than just retrieving information. Twilio has an API that allows you to write a script to send text messages to people. GitHub has an API for creating new repositories. Many services have APIs allowing computers to automate tasks that a person might otherwise have to do through a website - whether uploading a photo to Flickr, searching for a company name in a state database, or getting a list of garbage collection times for a municipality.

# %% [markdown]
# ## Limitations of APIs
#
# When working with APIs, there are some limitations you have to be aware of - especially relating to scope and scale.
#
# * **Scope** - Just because a company has an API and has information, it doesn't mean you can get all of the information you might want through their API
#
# * **Scale** - Some APIs are provided for free as a public service. Others you have to pay for, or allow you to perform activities (like sending a text message) that you pay for. Make sure that you know what the rate limits are and that your use case isn't going to need more API calls than you will be able to make.
#
# What else is good to know? **Every API is different!** There are some standards out there in terms of documentation and usage... but it's like the wild west - rapid expansion with few rules.
#
# With all that out of the way - Let's take a look at the `requests` library and its uses.

# %% [markdown]
# ### "Requests is the only Non-GMO HTTP library for Python, safe for human consumption."
#
# > "Requests allows you to send organic, grass-fed HTTP/1.1 requests, without the need for manual labor."
#
# Straight from the `requests` [documentation](https://pypi.org/project/requests/)

# %% [markdown]
# ### Types of Requests
#
# We will mostly use GET requests in order to get data, but there are other options.
#
# ![CRUD image from IntelliPaat](https://intellipaat.com/mediaFiles/2015/08/MongoDB-CRUD-operations.jpg)
#
# That's right - CRUD summarizes the kinds of requests you can make with most APIs.
#
# Let's say you are looking at an API for a car rental company like Hertz or Zipcar - the following different requests could generate these different responses:
#
# | Request               | Result                               | In CRUD Terms |
# | --------------------- | ------------------------------------ | ------------- |
# | GET /stores/          | User sees the list of stores         | Read          |
# | GET /rentals/         | User sees the history of car rentals | Read          |
# | POST /rentals/        | User rents a car                     | Create        |
# | PUT /rentals/{id}/    | User changes destination store       | Update        |
# | DELETE /rentals/{id}/ | User cancels the active car rental   | Delete        |

# %% [markdown]
# ### Let's get started!

# %%
import requests

# %%
# Don't already have the library? Uncomment the below code and install it locally
#!pip install requests

# %%
# Create a GET request, then check the type of object

r = requests.get('https://api.github.com/events') 
type(r)
# Out:
# requests.models.Response

# %%
# So what does this look like?
r.text
# Out:
# '[{"id":"22183782062","type":"WatchEvent","actor":{"id":33589711,"login":"tr717","display_login":"tr717","gravatar_id":"","url":"https://api.github.com/users/tr717","avatar_url":"https://avatars.githubusercontent.com/u/33589711?"},"repo":{"id":345074406,"name":"textflint/textflint","url":"https://api.github.com/repos/textflint/textflint"},"payload":{"action":"started"},"public":true,"created_at":"2022-06-06T15:37:15Z","org":{"id":80097570,"login":"textflint","gravatar_id":"","url":"https://api.github.com/orgs/textflint","avatar_url":"https://avatars.githubusercontent.com/u/80097570?"}},{"id":"22183782065","type":"CommitCommentEvent","actor":{"id":35613825,"login":"vercel[bot]","display_login":"vercel","gravatar_id":"","url":"https://api.github.com/users/vercel[bot]","avatar_url":"https://avatars.githubusercontent.com/u/35613825?"},"repo":{"id":500459599,"name":"Agusmac/Paperpillar-Next","url":"https://api.github.com/repos/Agusmac/Paperpillar-Next"},"payload":{"comment":{"url":"https://api.github.com/repos/Agusmac/Paperpillar-Next/comments/75442792","html_url":"https://github.com/Agusmac/Paperpillar-Next/commit/f1b43d4c8a4c7749c0e1186ff98969f6e8e320d3#commitcomment-75442792","id":75442792,"node_id":"CC_kwDOHdRoT84Efypo","user":{"login":"vercel[bot]","id":35613825,"node_id":"MDM6Qm90MzU2MTM4MjU=","avatar_url":"https://avatars.githubusercontent.com/in/8329?v=4","gravatar_id":"","url":"https://api.github.com/users/vercel%5Bbot%5D","html_url":"https://github.com/apps/vercel","followers_url":"https://api.github.com/users/vercel%5Bbot%5D/followers","following_url":"https://api.github.com/users/vercel%5Bbot%5D/following{/other_user}","gists_url":"https://api.github.com/users/vercel%5Bbot%5D/gists{/gist_id}","starred_url":"https://api.github.com/users/vercel%5Bbot%5D/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/vercel%5Bbot%5D/subscriptions","organizations_url":"https://api.github.com/users/vercel%5Bbot%5D/orgs","repos_url":"https://api.github.com/users/vercel%5Bbot%5D/repos","events_url":"https://api.github.com/users/vercel%5Bbot%5D/events{/privacy}","received_events_url":"https://api.github.com/users/vercel%5Bbot%5D/received_events","type":"Bot","site_admin":false},"position":null,"line":null,"path":null,"commit_id":"f1b43d4c8a4c7749c0e1186ff98969f6e8e320d3","created_at":"2022-06-06T15:37:15Z","updated_at":"2022-06-06T15:37:15Z","author_association":"NONE","body":"Successfully deployed to the following URLs:\\n\\n## paperpillar-next – ./\\n\\n[paperpillar-next-git-main-agusmac.vercel.app](https://paperpillar-next-git-main-agusmac.vercel.app)  \\n[paperpillar-next-agusmac.vercel.app](https://paperpillar-next-agusmac.vercel.app)  \\n[paperpillar-next.vercel.app](https://paperpillar-next.vercel.app)","reactions":{"url":"https://api.github.com/repos/Agusmac/Paperpillar-Next/comments/75442792/reactions","total_count":0,"+1":0,"-1":0,"laugh":0,"hooray":0,"confused":0,"heart":0,"rocket":0,"eyes":0}}},"public":true,"created_at":"2022-06-06T15:37:15Z"},{"id":"22183782053","type":"PullRequestEvent","actor":{"id":49699333,"login":"dependabot[bot]","display_login":"dependabot","gravatar_id":"","url":"https://api.github.com/users/dependabot[bot]","avatar_url":"https://avatars.githubusercontent.com/u/49699333?"},"repo":{"id":451828517,"name":"mirsella/powercontrol","url":"https://api.github.com/repos/mirsella/powercontrol"},"payload":{"action":"opened","number":117,"pull_request":{"url":"https://api.github.com/repos/mirsella/powercontrol/pulls/117","id":959256343,"node_id":"PR_kwDOGu5bJc45LRcX","html_url":"https://github.com/mirsella/powercontrol/pull/117","diff_url":"https://github.com/mirsella/powercontrol/pull/117.diff","patch_url":"https://github.com/mirsella/powercontrol/pull/117.patch","issue_url":"https://api.github.com/repos/mirsella/powercontrol/issues/117","number":117,"state":"open","locked":false,"title":"Bump typescript from 4.7.2 to 4.7.3 in /server","user":{"login":"dependabot[bot]","id":49699333,"node_i ...

# %% [markdown]
# ![Oh good heavens gif, from gfycat](https://thumbs.gfycat.com/ColdAmbitiousDogwoodtwigborer-size_restricted.gif)

# %% [markdown]
# Obviously you're never going to just scan that quickly for any data you need, we need to wrangle that response to make it usable.
#
# But first, let's look at some of the other attributes of `requests.models.Response` objects.
#
# We can check out all of the attributes [here](https://2.python-requests.org//en/v0.10.6/api/) in the documentation.

# %%
# Another attribute, what does this show us?
r.headers
# Out:
# {'Server': 'GitHub.com', 'Date': 'Mon, 06 Jun 2022 15:42:15 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'public, max-age=60, s-maxage=60', 'Vary': 'Accept, Accept-Encoding, Accept, X-Requested-With', 'ETag': 'W/"1dd2da3f525979c905a78fe7442f97bf1391c24ecf9b21ee5a162e07d83dfe6b"', 'Last-Modified': 'Mon, 06 Jun 2022 15:37:15 GMT', 'X-Poll-Interval': '60', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Link': '<https://api.github.com/events?page=2>; rel="next", <https://api.github.com/events?page=10>; rel="last"', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '0', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'Content-Encoding': 'gzip', 'X-RateLimit-Limit': '60', 'X-RateLimit-Remaining': '59', 'X-RateLimit-Reset': '1654533735', 'X-RateLimit-Resource': 'core', 'X-RateLimit-Used': '1', 'Accept-Ranges': 'bytes', 'Transfer-Encoding': 'chunked', 'X-GitHub-Request-Id': 'FC6D:7C42:14DC234:43C8B29:629E2057'}

# %% [markdown]
# ### Checking out the status of your request

# %%
# Another attribute
r.status_code
# Out:
# 200

# %% [markdown]
# ### [Types of status codes](https://http.cat/)
#
# 1xx - Informational responses
#
# 2xx - Success
# - 200 OK
# - 201 Created
# - 204 No Content
#
# 3xx - Redirection
#
# - 301 Moved Permanently (permanent URL redirection)
# - 304 Not Modified (A conditional GET or HEAD request has been received and would have resulted in a 200 OK response if it were not for the fact that the condition evaluated to false.)
#
# 4xx - Client errors
#
# - 400 Bad Request
# - 401 Unauthorized
# - 403 Forbidden
# - 404 Not Found
#
# 5xx - Server errors
#
# - 500 Internal Server Error

# %%
# Get status code for a "broken" link

r_broken = requests.get('https://api.github.com/fake-ending')
r_broken.status_code
# Out:
# 404

# %% [markdown]
# Can also explictly ask for the returned format to be json as a method.

# %% [markdown]
# #### A note on errors and exceptions with the Requests library
#
# There are a number of exceptions and error codes you need to be familiar with when using the Requests library in Python.
#
# - The Requests library will raise a ConnectionError exception if there is a network problem like a DNS failure, or refused connection
# - These are rare, but with invalid HTTP responses, Requests will also raise an HTTPError exception
# - A Timeout exception will be raised if a request times out
# - If and when a request exceeds the preconfigured number of maximum redirections, then a TooManyRedirects exception will be raised

# %%
# Going back to our working request - how does this look, compared to text?
r.json()
# Out:
# [{'id': '22183782062',
#   'type': 'WatchEvent',
#   'actor': {'id': 33589711,
#    'login': 'tr717',
#    'display_login': 'tr717',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tr717',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33589711?'},
#   'repo': {'id': 345074406,
#    'name': 'textflint/textflint',
#    'url': 'https://api.github.com/repos/textflint/textflint'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2022-06-06T15:37:15Z',
#   'org': {'id': 80097570,
#    'login': 'textflint',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/textflint',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/80097570?'}},
#  {'id': '22183782065',
#   'type': 'CommitCommentEvent',
#   'actor': {'id': 35613825,
#    'login': 'vercel[bot]',
#    'display_login': 'vercel',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vercel[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/35613825?'},
#   'repo': {'id': 500459599,
#    'name': 'Agusmac/Paperpillar-Next',
#    'url': 'https://api.github.com/repos/Agusmac/Paperpillar-Next'},
#   'payload': {'comment': {'url': 'https://api.github.com/repos/Agusmac/Paperpillar-Next/comments/75442792',
#     'html_url': 'https://github.com/Agusmac/Paperpillar-Next/commit/f1b43d4c8a4c7749c0e1186ff98969f6e8e320d3#commitcomment-75442792',
#     'id': 75442792,
#     'node_id': 'CC_kwDOHdRoT84Efypo',
#     'user': {'login': 'vercel[bot]',
#      'id': 35613825,
#      'node_id': 'MDM6Qm90MzU2MTM4MjU=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/8329?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/vercel%5Bbot%5D',
#      'html_url': 'https://github.com/apps/vercel',
#      'followers_url': 'https://api.github.com/users/vercel%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/vercel%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/vercel%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/vercel%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/vercel%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/vercel%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/vercel%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/vercel%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/vercel%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'position': None,
#     'line': None,
#     'path': None,
#     'commit_id': 'f1b43d4c8a4c7749c0e1186ff98969f6e8e320d3',
#     'created_at': '2022-06-06T15:37:15Z',
#     'updated_at': '2022-06-06T15:37:15Z',
#     'author_association': 'NONE',
#     'body': 'Successfully deployed to the following URLs:\n\n## paperpillar-next – ./\n\n[paperpillar-next-git-main-agusmac.vercel.app](https://paperpillar-next-git-main-agusmac.vercel.app)  \n[paperpillar-next-agusmac.vercel.app](https://paperpillar-next-agusmac.vercel.app)  \n[paperpillar-next.vercel.app](https://paperpillar-next.vercel.app)',
#     'reactions': {'url': 'https://api.github.com/repos/Agusmac/Paperpillar-Next/comments/75442792/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0}}},
#   'public': True,
#   'created_at': '2022-06-06T15:37:15Z'},
#  {'id': '22183782053',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 451828517,
#    'name': 'mirsella/powercontrol',
#    'url': 'https://api.github.com/repos/mirsella/powercontrol'},
#   'payload': {'action': 'opened',
#    'number': 117,
#    'pull_request': {'url': 'https://api.github.com/repos/mirsella/powercontrol/pulls/117',
#     'id': 959256343,
#     'node_id': 'PR_kwDOGu5bJc45LRcX',
#     'html_url': 'https://github.com/mirsella/powercontrol/pull/117',
#     'diff_url': 'https://github.com/mirsella/powercontrol/pull/117.diff',
#     'patch_url': 'https://github.com/mirsella/powercontrol/pull/117.patch',
#     'issue_url': 'https://api.github.com/repos/mirsella/powercontrol/issues/117',
#     'number': 117,
#     'state': 'open',
#     'locked': False,
#     'title': 'Bump typescript from 4.7.2 to 4.7.3 in /server',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [typescript](https://github.com/Microsoft/TypeScript) from 4.7.2 to 4.7.3.\n<details>\n<summary>Release notes</summary>\n<p><em>Sourced from <a href="https://github.com/Microsoft/TypeScript/releases">typescript\'s releases</a>.</em></p>\n<blockquote>\n<h2>TypeScript 4.7.3</h2>\n<p>For release notes, check out the <a href="https://devblogs.microsoft.com/typescript/announcing-typescript-4-7/">release announcement</a>.</p>\n<p>For the complete list of fixed issues, check out the</p>\n<ul>\n<li><a href="https://github.com/microsoft/TypeScript/issues?q=milestone%3A%22TypeScript+4.7.0%22+">fixed issues query for Typescript 4.7.0 (Beta)</a>.</li>\n<li><a href="https://github.com/microsoft/TypeScript/issues?q=milestone%3A%22TypeScript+4.7.1%22+">fixed issues query for Typescript 4.7.1 (RC)</a>.</li>\n<li><a href="https://github.com/microsoft/TypeScript/issues?q=milestone%3A%22TypeScript+4.7.2%22+">fixed issues query for Typescript 4.7.2 (Stable)</a>.</li>\n<li><a href="https://github.com/microsoft/TypeScript/issues?q=milestone%3A%22TypeScript+4.7.3%22+">fixed issues query for Typescript 4.7.3 (Stable)</a>.</li>\n</ul>\n<p>Downloads are available on:</p>\n<ul>\n<li><a href="https://www.npmjs.com/package/typescript">npm</a></li>\n<li><a href="https://marketplace.visualstudio.com/items?itemName=TypeScriptTeam.TypeScript-473">Visual Studio 2022/2019</a> (<a href="https://github.com/Microsoft/TypeScript/wiki/Updating-TypeScript-in-Visual-Studio-2017">Select new version in project options</a>)</li>\n<li><a href="https://www.nuget.org/packages/Microsoft.TypeScript.MSBuild">NuGet package</a></li>\n</ul>\n</blockquote>\n</details>\n<details>\n<summary>Commits</summary>\n<ul>\n<li><a href="https://github.com/microsoft/TypeScript/commit/e5050bb405548a127b0a48a264bade6fd662ce06"><code>e5050bb</code></a> Bump version to 4.7.3 and LKG</li>\n<li><a href="https://github.com/microsoft/TypeScript/commit/4c4c80322a1512391d2708a9008e910401c16ca1"><code>4c4c803</code></a> 🤖 Pick PR <a href="https://github-redirect.dependabot.com/Microsoft/TypeScript/issues/49360">#49360</a> (Expose import mode calculation func...) into release-4.7 (#...</li>\n<li><a href="https://github.com/microsoft/TypeScript/commit/3ce08c6ba14eb6f9062f29462bd0ac2d5bada5c5"><code>3ce08c6</code></a> fix(49223): checker.getTypeAtLocation for ExpressionWithTypeArguments returns...</li>\n<li><a href="https://github.com/microsoft/TypeScript/commit/3bf0d30686e81c8f91c954eb0bd18a19b0a544b2"><code>3bf0d30</code></a> Pick PR <a href="https://github-redirect.dependabot.com/Microsoft/TypeScript/issues/49356">#49356</a> (Add nightly-only error on ImportType resolution mode assertio...</li>\n<li><a href="https://github.com/microsoft/TypeScript/commit/5f7f0b1d57fdbc166c3969a3dd3f19f15ba0388e"><code>5f7f0b1</code></a> Cherry-pick PR <a href="https://github-redirect.dependabot.com/Microsoft/TypeScript/issues/49361">#49361</a> into release-4.7 (<a href="https://github-redirect.dependabot.com/Microsoft/TypeScript/issues/49364">#49364</a>)</li>\n<li><a href="https://github.com/microsoft/TypeScript/commit/c07d883428845a321c7379c7d326e13f7aad8974"><code>c07d883</code></a> Cherry-pick PR <a href="https://github-redirect.dependabot.com/Microsoft/TypeScript/issues/49313">#49313</a> into release-4.7 (<a href="https://github-redirect.dependabot.com/Microsoft/TypeScript/issues/49359">#49359</a>)</li>\n<li><a href="https://github.com/microsoft/TypeScript/commit/197aaef55fe79b9a0218a6fdea79348274ee34bc"><code>197aaef</code></a> Cherry-pick PR <a href="https://github-redirect.dependabot.com/Microsoft/TypeScript/issues/49246">#49246</a> into release-4.7 (<a href="https://github-redirect.dependabot.com/Microsoft/TypeScript/issues/49250">#49250</a>)</li>\n<li><a href="https://github.com/microsoft/TypeScript/commit/35519356ede14b7d87b37e3612937e475b5db86d"><code>3551935</code></a> Cherry-pick PR <a href="https://github-redirect.dependabot.com/Microsoft/TypeScript/issues/49268">#49268</a> into release- ...
#     'created_at': '2022-06-06T15:37:14Z',
#     'updated_at': '2022-06-06T15:37:14Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/mirsella/powercontrol/pulls/117/commits',
#     'review_comments_url': 'https://api.github.com/repos/mirsella/powercontrol/pulls/117/comments',
#     'review_comment_url': 'https://api.github.com/repos/mirsella/powercontrol/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/mirsella/powercontrol/issues/117/comments',
#     'statuses_url': 'https://api.github.com/repos/mirsella/powercontrol/statuses/dcc9bbc70f569eb90731788aa0bbeb75ae8ea373',
#     'head': {'label': 'mirsella:dependabot/npm_and_yarn/server/typescript-4.7.3',
#      'ref': 'dependabot/npm_and_yarn/server/typescript-4.7.3',
#      'sha': 'dcc9bbc70f569eb90731788aa0bbeb75ae8ea373',
#      'user': {'login': 'mirsella',
#       'id': 45905567,
#       'node_id': 'MDQ6VXNlcjQ1OTA1NTY3',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/45905567?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/mirsella',
#       'html_url': 'https://github.com/mirsella',
#       'followers_url': 'https://api.github.com/users/mirsella/followers',
#       'following_url': 'https://api.github.com/users/mirsella/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/mirsella/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/mirsella/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/mirsella/subscriptions',
#       'organizations_url': 'https://api.github.com/users/mirsella/orgs',
#       'repos_url': 'https://api.github.com/users/mirsella/repos',
#       'events_url': 'https://api.github.com/users/mirsella/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/mirsella/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 451828517,
#       'node_id': 'R_kgDOGu5bJQ',
#       'name': 'powercontrol',
#       'full_name': 'mirsella/powercontrol',
#       'private': False,
#       'owner': {'login': 'mirsella',
#        'id': 45905567,
#        'node_id': 'MDQ6VXNlcjQ1OTA1NTY3',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/45905567?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/mirsella',
#        'html_url': 'https://github.com/mirsella',
#        'followers_url': 'https://api.github.com/users/mirsella/followers',
#        'following_url': 'https://api.github.com/users/mirsella/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/mirsella/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/mirsella/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/mirsella/subscriptions',
#        'organizations_url': 'https://api.github.com/users/mirsella/orgs',
#        'repos_url': 'https://api.github.com/users/mirsella/repos',
#        'events_url': 'https://api.github.com/users/mirsella/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/mirsella/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/mirsella/powercontrol',
#       'description': 'raspberry pi controlled GRUB and PC power with a relay, with a app.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/mirsella/powercontrol',
#       'forks_url': 'https://api.github.com/repos/mirsella/powercontrol/forks',
#       'keys_url': 'https://api.github.com/repos/mirsella/powercontrol/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/mirsella/powercontrol/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/mirsella/powercontrol/teams',
#       'hooks_url': 'https://api.github.com/repos/mirsella/powercontrol/hooks',
#       'issue_events_url': 'https://api.github.com/repos/mirsella/powercontrol/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/mirsella/powercontrol/events',
#       'assignees_url': 'https://api.github.com/repos/mirsella/powercontrol/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/mirsella/powercontrol/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/mirsella/powercontrol/tags',
#       'blobs_url': 'https://api.github.com/repos/mirsella/powercontrol/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/mirsella/powercontrol/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/mirsella/powercontrol/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/mirsella/powercontrol/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/mirsella/powercontrol/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/mirsella/powercontrol/languages',
#       'stargazers_url': 'https://api.github.com/repos/mirsella/powercontrol/stargazers',
#       'contributors_url': 'https://api.github.com/repos/mirsella/powercontrol/contributors',
#       'subscribers_url': 'https://api.github.com/repos/mirsella/powercontrol/subscribers',
#       'subscription_url': 'https://api.github.com/repos/mirsella/powercontrol/subscription',
#       'commits_url': 'https://api.github.com/repos/mirsella/powercontrol/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/mirsella/powercontrol/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/mirsella/powercontrol/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/mirsella/powercontrol/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/mirsella/powercontrol/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/mirsella/powercontrol/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/mirsella/powercontrol/merges',
#       'archive_url': 'https://api.github.com/repos/mirsella/powercontrol/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/mirsella/powercontrol/downloads',
#       'issues_url': 'https://api.github.com/repos/mirsella/powercontrol/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/mirsella/powercontrol/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/mirsella/powercontrol/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/mirsella/powercontrol/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/mirsella/powercontrol/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/mirsella/powercontrol/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/mirsella/powercontrol/deployments',
#       'created_at': '2022-01-25T10:16:10Z',
#       'updated_at': '2022-05-19T06:53:16Z',
#       'pushed_at': '2022-06-06T15:37:15Z',
#       'git_url': 'git://github.com/mirsella/powercontrol.git',
#       'ssh_url': 'git@github.com:mirsella/powercontrol.git',
#       'clone_url': 'https://github.com/mirsella/powercontrol.git',
#       'svn_url': 'https://github.com/mirsella/powercontrol',
#       'homepage': '',
#       'size': 1921,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Vue',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': ['capacitor',
#        'grub',
#        'raspberry-pi',
#        'relay',
#        'serial',
#        'vite',
#        'vuejs'],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 2,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': 'mirsella:main',
#      'ref': 'main',
#      'sha': 'e17b5be371e3c7f3d799cf11497e7fb890bc4ed8',
#      'user': {'login': 'mirsella',
#       'id': 45905567,
#       'node_id': 'MDQ6VXNlcjQ1OTA1NTY3',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/45905567?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/mirsella',
#       'html_url': 'https://github.com/mirsella',
#       'followers_url': 'https://api.github.com/users/mirsella/followers',
#       'following_url': 'https://api.github.com/users/mirsella/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/mirsella/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/mirsella/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/mirsella/subscriptions',
#       'organizations_url': 'https://api.github.com/users/mirsella/orgs',
#       'repos_url': 'https://api.github.com/users/mirsella/repos',
#       'events_url': 'https://api.github.com/users/mirsella/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/mirsella/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 451828517,
#       'node_id': 'R_kgDOGu5bJQ',
#       'name': 'powercontrol',
#       'full_name': 'mirsella/powercontrol',
#       'private': False,
#       'owner': {'login': 'mirsella',
#        'id': 45905567,
#        'node_id': 'MDQ6VXNlcjQ1OTA1NTY3',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/45905567?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/mirsella',
#        'html_url': 'https://github.com/mirsella',
#        'followers_url': 'https://api.github.com/users/mirsella/followers',
#        'following_url': 'https://api.github.com/users/mirsella/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/mirsella/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/mirsella/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/mirsella/subscriptions',
#        'organizations_url': 'https://api.github.com/users/mirsella/orgs',
#        'repos_url': 'https://api.github.com/users/mirsella/repos',
#        'events_url': 'https://api.github.com/users/mirsella/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/mirsella/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/mirsella/powercontrol',
#       'description': 'raspberry pi controlled GRUB and PC power with a relay, with a app.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/mirsella/powercontrol',
#       'forks_url': 'https://api.github.com/repos/mirsella/powercontrol/forks',
#       'keys_url': 'https://api.github.com/repos/mirsella/powercontrol/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/mirsella/powercontrol/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/mirsella/powercontrol/teams',
#       'hooks_url': 'https://api.github.com/repos/mirsella/powercontrol/hooks',
#       'issue_events_url': 'https://api.github.com/repos/mirsella/powercontrol/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/mirsella/powercontrol/events',
#       'assignees_url': 'https://api.github.com/repos/mirsella/powercontrol/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/mirsella/powercontrol/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/mirsella/powercontrol/tags',
#       'blobs_url': 'https://api.github.com/repos/mirsella/powercontrol/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/mirsella/powercontrol/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/mirsella/powercontrol/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/mirsella/powercontrol/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/mirsella/powercontrol/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/mirsella/powercontrol/languages',
#       'stargazers_url': 'https://api.github.com/repos/mirsella/powercontrol/stargazers',
#       'contributors_url': 'https://api.github.com/repos/mirsella/powercontrol/contributors',
#       'subscribers_url': 'https://api.github.com/repos/mirsella/powercontrol/subscribers',
#       'subscription_url': 'https://api.github.com/repos/mirsella/powercontrol/subscription',
#       'commits_url': 'https://api.github.com/repos/mirsella/powercontrol/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/mirsella/powercontrol/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/mirsella/powercontrol/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/mirsella/powercontrol/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/mirsella/powercontrol/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/mirsella/powercontrol/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/mirsella/powercontrol/merges',
#       'archive_url': 'https://api.github.com/repos/mirsella/powercontrol/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/mirsella/powercontrol/downloads',
#       'issues_url': 'https://api.github.com/repos/mirsella/powercontrol/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/mirsella/powercontrol/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/mirsella/powercontrol/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/mirsella/powercontrol/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/mirsella/powercontrol/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/mirsella/powercontrol/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/mirsella/powercontrol/deployments',
#       'created_at': '2022-01-25T10:16:10Z',
#       'updated_at': '2022-05-19T06:53:16Z',
#       'pushed_at': '2022-06-06T15:37:15Z',
#       'git_url': 'git://github.com/mirsella/powercontrol.git',
#       'ssh_url': 'git@github.com:mirsella/powercontrol.git',
#       'clone_url': 'https://github.com/mirsella/powercontrol.git',
#       'svn_url': 'https://github.com/mirsella/powercontrol',
#       'homepage': '',
#       'size': 1921,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Vue',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': ['capacitor',
#        'grub',
#        'raspberry-pi',
#        'relay',
#        'serial',
#        'vite',
#        'vuejs'],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 2,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/mirsella/powercontrol/pulls/117'},
#      'html': {'href': 'https://github.com/mirsella/powercontrol/pull/117'},
#      'issue': {'href': 'https://api.github.com/repos/mirsella/powercontrol/issues/117'},
#      'comments': {'href': 'https://api.github.com/repos/mirsella/powercontrol/issues/117/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/mirsella/powercontrol/pulls/117/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/mirsella/powercontrol/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/mirsella/powercontrol/pulls/117/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/mirsella/powercontrol/statuses/dcc9bbc70f569eb90731788aa0bbeb75ae8ea373'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 8,
#     'deletions': 8,
#     'changed_files': 2}},
#   'public': True,
#   'created_at': '2022-06-06T15:37:15Z'},
#  {'id': '22183782022',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 18567580,
#    'login': 'conda-forge-linter',
#    'display_login': 'conda-forge-linter',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/conda-forge-linter',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18567580?'},
#   'repo': {'id': 376372758,
#    'name': 'conda-forge/tinyobjloader-feedstock',
#    'url': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock'},
#   'payload': {'action': 'opened',
#    'number': 4,
#    'pull_request': {'url': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/pulls/4',
#     'id': 959256342,
#     'node_id': 'PR_kwDOFm7-Fs45LRcW',
#     'html_url': 'https://github.com/conda-forge/tinyobjloader-feedstock/pull/4',
#     'diff_url': 'https://github.com/conda-forge/tinyobjloader-feedstock/pull/4.diff',
#     'patch_url': 'https://github.com/conda-forge/tinyobjloader-feedstock/pull/4.patch',
#     'issue_url': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/issues/4',
#     'number': 4,
#     'state': 'open',
#     'locked': False,
#     'title': '[ci skip] adding user @traversaro',
#     'user': {'login': 'conda-forge-linter',
#      'id': 18567580,
#      'node_id': 'MDQ6VXNlcjE4NTY3NTgw',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/18567580?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/conda-forge-linter',
#      'html_url': 'https://github.com/conda-forge-linter',
#      'followers_url': 'https://api.github.com/users/conda-forge-linter/followers',
#      'following_url': 'https://api.github.com/users/conda-forge-linter/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/conda-forge-linter/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/conda-forge-linter/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/conda-forge-linter/subscriptions',
#      'organizations_url': 'https://api.github.com/users/conda-forge-linter/orgs',
#      'repos_url': 'https://api.github.com/users/conda-forge-linter/repos',
#      'events_url': 'https://api.github.com/users/conda-forge-linter/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/conda-forge-linter/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': "\nHi! This is the friendly automated conda-forge-webservice.\n\nI've added user @traversaro as instructed in #3.\n\nMerge this PR to add the user. Please do not rerender this PR or change it in any way. It has `[ci skip]` in the commit message to avoid pushing a new build and so the build configuration in the feedstock should not be changed.\n\nPlease contact [conda-forge/core](https://conda-forge.org/docs/maintainer/maintainer_faq.html#mfaq-contact-core) to have this PR merged, if the maintainer is unresponsive.\n\nFixes #3",
#     'created_at': '2022-06-06T15:37:14Z',
#     'updated_at': '2022-06-06T15:37:14Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/pulls/4/commits',
#     'review_comments_url': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/pulls/4/comments',
#     'review_comment_url': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/issues/4/comments',
#     'statuses_url': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/statuses/81af208a05b98b6c591b1667aa270645c6367692',
#     'head': {'label': 'conda-forge-linter:conda_forge_admin_3',
#      'ref': 'conda_forge_admin_3',
#      'sha': '81af208a05b98b6c591b1667aa270645c6367692',
#      'user': {'login': 'conda-forge-linter',
#       'id': 18567580,
#       'node_id': 'MDQ6VXNlcjE4NTY3NTgw',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/18567580?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/conda-forge-linter',
#       'html_url': 'https://github.com/conda-forge-linter',
#       'followers_url': 'https://api.github.com/users/conda-forge-linter/followers',
#       'following_url': 'https://api.github.com/users/conda-forge-linter/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/conda-forge-linter/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/conda-forge-linter/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/conda-forge-linter/subscriptions',
#       'organizations_url': 'https://api.github.com/users/conda-forge-linter/orgs',
#       'repos_url': 'https://api.github.com/users/conda-forge-linter/repos',
#       'events_url': 'https://api.github.com/users/conda-forge-linter/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/conda-forge-linter/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 500491893,
#       'node_id': 'R_kgDOHdTmdQ',
#       'name': 'tinyobjloader-feedstock',
#       'full_name': 'conda-forge-linter/tinyobjloader-feedstock',
#       'private': False,
#       'owner': {'login': 'conda-forge-linter',
#        'id': 18567580,
#        'node_id': 'MDQ6VXNlcjE4NTY3NTgw',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/18567580?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/conda-forge-linter',
#        'html_url': 'https://github.com/conda-forge-linter',
#        'followers_url': 'https://api.github.com/users/conda-forge-linter/followers',
#        'following_url': 'https://api.github.com/users/conda-forge-linter/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/conda-forge-linter/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/conda-forge-linter/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/conda-forge-linter/subscriptions',
#        'organizations_url': 'https://api.github.com/users/conda-forge-linter/orgs',
#        'repos_url': 'https://api.github.com/users/conda-forge-linter/repos',
#        'events_url': 'https://api.github.com/users/conda-forge-linter/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/conda-forge-linter/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/conda-forge-linter/tinyobjloader-feedstock',
#       'description': 'A conda-smithy repository for tinyobjloader.',
#       'fork': True,
#       'url': 'https://api.github.com/repos/conda-forge-linter/tinyobjloader-feedstock',
#       'forks_url': 'https://api.github.com/repos/conda-forge-linter/tinyobjloader-feedstock/forks',
#       'keys_url': 'https://api.github.com/repos/conda-forge-linter/tinyobjloader-feedstock/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/conda-forge-linter/tinyobjloader-feedstock/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/conda-forge-linter/tinyobjloader-feedstock/teams',
#       'hooks_url': 'https://api.github.com/repos/conda-forge-linter/tinyobjloader-feedstock/hooks',
#       'issue_events_url': 'https://api.github.com/repos/conda-forge-linter/tinyobjloader-feedstock/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/conda-forge-linter/tinyobjloader-feedstock/events',
#       'assignees_url': 'https://api.github.com/repos/conda-forge-linter/tinyobjloader-feedstock/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/conda-forge-linter/tinyobjloader-feedstock/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/conda-forge-linter/tinyobjloader-feedstock/tags',
#       'blobs_url': 'https://api.github.com/repos/conda-forge-linter/tinyobjloader-feedstock/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/conda-forge-linter/tinyobjloader-feedstock/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/conda-forge-linter/tinyobjloader-feedstock/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/conda-forge-linter/tinyobjloader-feedstock/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/conda-forge-linter/tinyobjloader-feedstock/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/conda-forge-linter/tinyobjloader-feedstock/languages',
#       'stargazers_url': 'https://api.github.com/repos/conda-forge-linter/tinyobjloader-feedstock/stargazers',
#       'contributors_url': 'https://api.github.com/repos/conda-forge-linter/tinyobjloader-feedstock/contributors',
#       'subscribers_url': 'https://api.github.com/repos/conda-forge-linter/tinyobjloader-feedstock/subscribers',
#       'subscription_url': 'https://api.github.com/repos/conda-forge-linter/tinyobjloader-feedstock/subscription',
#       'commits_url': 'https://api.github.com/repos/conda-forge-linter/tinyobjloader-feedstock/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/conda-forge-linter/tinyobjloader-feedstock/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/conda-forge-linter/tinyobjloader-feedstock/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/conda-forge-linter/tinyobjloader-feedstock/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/conda-forge-linter/tinyobjloader-feedstock/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/conda-forge-linter/tinyobjloader-feedstock/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/conda-forge-linter/tinyobjloader-feedstock/merges',
#       'archive_url': 'https://api.github.com/repos/conda-forge-linter/tinyobjloader-feedstock/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/conda-forge-linter/tinyobjloader-feedstock/downloads',
#       'issues_url': 'https://api.github.com/repos/conda-forge-linter/tinyobjloader-feedstock/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/conda-forge-linter/tinyobjloader-feedstock/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/conda-forge-linter/tinyobjloader-feedstock/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/conda-forge-linter/tinyobjloader-feedstock/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/conda-forge-linter/tinyobjloader-feedstock/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/conda-forge-linter/tinyobjloader-feedstock/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/conda-forge-linter/tinyobjloader-feedstock/deployments',
#       'created_at': '2022-06-06T15:37:12Z',
#       'updated_at': '2021-12-17T08:12:22Z',
#       'pushed_at': '2022-06-06T15:37:13Z',
#       'git_url': 'git://github.com/conda-forge-linter/tinyobjloader-feedstock.git',
#       'ssh_url': 'git@github.com:conda-forge-linter/tinyobjloader-feedstock.git',
#       'clone_url': 'https://github.com/conda-forge-linter/tinyobjloader-feedstock.git',
#       'svn_url': 'https://github.com/conda-forge-linter/tinyobjloader-feedstock',
#       'homepage': None,
#       'size': 17,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': None,
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'bsd-3-clause',
#        'name': 'BSD 3-Clause "New" or "Revised" License',
#        'spdx_id': 'BSD-3-Clause',
#        'url': 'https://api.github.com/licenses/bsd-3-clause',
#        'node_id': 'MDc6TGljZW5zZTU='},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': 'conda-forge:main',
#      'ref': 'main',
#      'sha': '59664adb6eb8ba8449fa6721aaa9c1b0011bc9d2',
#      'user': {'login': 'conda-forge',
#       'id': 11897326,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjExODk3MzI2',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/11897326?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/conda-forge',
#       'html_url': 'https://github.com/conda-forge',
#       'followers_url': 'https://api.github.com/users/conda-forge/followers',
#       'following_url': 'https://api.github.com/users/conda-forge/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/conda-forge/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/conda-forge/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/conda-forge/subscriptions',
#       'organizations_url': 'https://api.github.com/users/conda-forge/orgs',
#       'repos_url': 'https://api.github.com/users/conda-forge/repos',
#       'events_url': 'https://api.github.com/users/conda-forge/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/conda-forge/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 376372758,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzNzYzNzI3NTg=',
#       'name': 'tinyobjloader-feedstock',
#       'full_name': 'conda-forge/tinyobjloader-feedstock',
#       'private': False,
#       'owner': {'login': 'conda-forge',
#        'id': 11897326,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjExODk3MzI2',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/11897326?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/conda-forge',
#        'html_url': 'https://github.com/conda-forge',
#        'followers_url': 'https://api.github.com/users/conda-forge/followers',
#        'following_url': 'https://api.github.com/users/conda-forge/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/conda-forge/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/conda-forge/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/conda-forge/subscriptions',
#        'organizations_url': 'https://api.github.com/users/conda-forge/orgs',
#        'repos_url': 'https://api.github.com/users/conda-forge/repos',
#        'events_url': 'https://api.github.com/users/conda-forge/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/conda-forge/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/conda-forge/tinyobjloader-feedstock',
#       'description': 'A conda-smithy repository for tinyobjloader.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock',
#       'forks_url': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/forks',
#       'keys_url': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/teams',
#       'hooks_url': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/hooks',
#       'issue_events_url': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/events',
#       'assignees_url': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/tags',
#       'blobs_url': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/languages',
#       'stargazers_url': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/stargazers',
#       'contributors_url': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/contributors',
#       'subscribers_url': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/subscribers',
#       'subscription_url': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/subscription',
#       'commits_url': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/merges',
#       'archive_url': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/downloads',
#       'issues_url': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/deployments',
#       'created_at': '2021-06-12T19:51:17Z',
#       'updated_at': '2021-12-17T08:12:22Z',
#       'pushed_at': '2022-05-27T19:39:29Z',
#       'git_url': 'git://github.com/conda-forge/tinyobjloader-feedstock.git',
#       'ssh_url': 'git@github.com:conda-forge/tinyobjloader-feedstock.git',
#       'clone_url': 'https://github.com/conda-forge/tinyobjloader-feedstock.git',
#       'svn_url': 'https://github.com/conda-forge/tinyobjloader-feedstock',
#       'homepage': None,
#       'size': 17,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': None,
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 3,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 3,
#       'license': {'key': 'bsd-3-clause',
#        'name': 'BSD 3-Clause "New" or "Revised" License',
#        'spdx_id': 'BSD-3-Clause',
#        'url': 'https://api.github.com/licenses/bsd-3-clause',
#        'node_id': 'MDc6TGljZW5zZTU='},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 3,
#       'open_issues': 3,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/pulls/4'},
#      'html': {'href': 'https://github.com/conda-forge/tinyobjloader-feedstock/pull/4'},
#      'issue': {'href': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/issues/4'},
#      'comments': {'href': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/issues/4/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/pulls/4/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/pulls/4/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/conda-forge/tinyobjloader-feedstock/statuses/81af208a05b98b6c591b1667aa270645c6367692'}},
#     'author_association': 'NONE',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': True,
#     'commits': 1,
#     'additions': 2,
#     'deletions': 1,
#     'changed_files': 2}},
#   'public': True,
#   'created_at': '2022-06-06T15:37:15Z',
#   'org': {'id': 11897326,
#    'login': 'conda-forge',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/conda-forge',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11897326?'}},
#  {'id': '22183781988',
#   'type': 'PushEvent',
#   'actor': {'id': 93227343,
#    'login': 'tf-vcs-testing',
#    'display_login': 'tf-vcs-testing',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tf-vcs-testing',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/93227343?'},
#   'repo': {'id': 500491661,
#    'name': 'tf-vcs-e2e/e2e-gh-89432afc-e5c5-d19c-1e5b-481f09398b6e',
#    'url': 'https://api.github.com/repos/tf-vcs-e2e/e2e-gh-89432afc-e5c5-d19c-1e5b-481f09398b6e'},
#   'payload': {'push_id': 10083792169,
#    'size': 1,
# ...
#      'ref': 'home_fragment_backend',
#      'sha': '9af6027eea2d1dcf3e9185bb5df2dab6ebe25746',
#      'user': {'login': 'samuelassis',
#       'id': 48067228,
#       'node_id': 'MDQ6VXNlcjQ4MDY3MjI4',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/48067228?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/samuelassis',
#       'html_url': 'https://github.com/samuelassis',
#       'followers_url': 'https://api.github.com/users/samuelassis/followers',
#       'following_url': 'https://api.github.com/users/samuelassis/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/samuelassis/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/samuelassis/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/samuelassis/subscriptions',
#       'organizations_url': 'https://api.github.com/users/samuelassis/orgs',
#       'repos_url': 'https://api.github.com/users/samuelassis/repos',
#       'events_url': 'https://api.github.com/users/samuelassis/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/samuelassis/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 477927943,
#       'node_id': 'R_kgDOHHyaBw',
#       'name': 'PDS-PrecoNoPosto',
#       'full_name': 'samuelassis/PDS-PrecoNoPosto',
#       'private': False,
#       'owner': {'login': 'samuelassis',
#        'id': 48067228,
#        'node_id': 'MDQ6VXNlcjQ4MDY3MjI4',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/48067228?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/samuelassis',
#        'html_url': 'https://github.com/samuelassis',
#        'followers_url': 'https://api.github.com/users/samuelassis/followers',
#        'following_url': 'https://api.github.com/users/samuelassis/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/samuelassis/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/samuelassis/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/samuelassis/subscriptions',
#        'organizations_url': 'https://api.github.com/users/samuelassis/orgs',
#        'repos_url': 'https://api.github.com/users/samuelassis/repos',
#        'events_url': 'https://api.github.com/users/samuelassis/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/samuelassis/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/samuelassis/PDS-PrecoNoPosto',
#       'description': 'Repositório para projeto da disciplina de Praticas de Desenvolvimento de Software -  UFMG',
#       'fork': False,
#       'url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto',
#       'forks_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/forks',
#       'keys_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/teams',
#       'hooks_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/hooks',
#       'issue_events_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/events',
#       'assignees_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/tags',
#       'blobs_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/languages',
#       'stargazers_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/stargazers',
#       'contributors_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/contributors',
#       'subscribers_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/subscribers',
#       'subscription_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/subscription',
#       'commits_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/merges',
#       'archive_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/downloads',
#       'issues_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/deployments',
#       'created_at': '2022-04-05T01:01:31Z',
#       'updated_at': '2022-05-22T21:33:19Z',
#       'pushed_at': '2022-06-06T15:37:13Z',
#       'git_url': 'git://github.com/samuelassis/PDS-PrecoNoPosto.git',
#       'ssh_url': 'git@github.com:samuelassis/PDS-PrecoNoPosto.git',
#       'clone_url': 'https://github.com/samuelassis/PDS-PrecoNoPosto.git',
#       'svn_url': 'https://github.com/samuelassis/PDS-PrecoNoPosto',
#       'homepage': None,
#       'size': 241,
#       'stargazers_count': 1,
#       'watchers_count': 1,
#       'language': 'Kotlin',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 1,
#       'default_branch': 'main'}},
#     'base': {'label': 'samuelassis:main',
#      'ref': 'main',
#      'sha': '2c21a3270b82ab0b62d1dc27846a35518da4a1e9',
#      'user': {'login': 'samuelassis',
#       'id': 48067228,
#       'node_id': 'MDQ6VXNlcjQ4MDY3MjI4',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/48067228?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/samuelassis',
#       'html_url': 'https://github.com/samuelassis',
#       'followers_url': 'https://api.github.com/users/samuelassis/followers',
#       'following_url': 'https://api.github.com/users/samuelassis/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/samuelassis/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/samuelassis/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/samuelassis/subscriptions',
#       'organizations_url': 'https://api.github.com/users/samuelassis/orgs',
#       'repos_url': 'https://api.github.com/users/samuelassis/repos',
#       'events_url': 'https://api.github.com/users/samuelassis/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/samuelassis/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 477927943,
#       'node_id': 'R_kgDOHHyaBw',
#       'name': 'PDS-PrecoNoPosto',
#       'full_name': 'samuelassis/PDS-PrecoNoPosto',
#       'private': False,
#       'owner': {'login': 'samuelassis',
#        'id': 48067228,
#        'node_id': 'MDQ6VXNlcjQ4MDY3MjI4',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/48067228?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/samuelassis',
#        'html_url': 'https://github.com/samuelassis',
#        'followers_url': 'https://api.github.com/users/samuelassis/followers',
#        'following_url': 'https://api.github.com/users/samuelassis/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/samuelassis/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/samuelassis/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/samuelassis/subscriptions',
#        'organizations_url': 'https://api.github.com/users/samuelassis/orgs',
#        'repos_url': 'https://api.github.com/users/samuelassis/repos',
#        'events_url': 'https://api.github.com/users/samuelassis/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/samuelassis/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/samuelassis/PDS-PrecoNoPosto',
#       'description': 'Repositório para projeto da disciplina de Praticas de Desenvolvimento de Software -  UFMG',
#       'fork': False,
#       'url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto',
#       'forks_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/forks',
#       'keys_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/teams',
#       'hooks_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/hooks',
#       'issue_events_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/events',
#       'assignees_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/tags',
#       'blobs_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/languages',
#       'stargazers_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/stargazers',
#       'contributors_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/contributors',
#       'subscribers_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/subscribers',
#       'subscription_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/subscription',
#       'commits_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/merges',
#       'archive_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/downloads',
#       'issues_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/deployments',
#       'created_at': '2022-04-05T01:01:31Z',
#       'updated_at': '2022-05-22T21:33:19Z',
#       'pushed_at': '2022-06-06T15:37:13Z',
#       'git_url': 'git://github.com/samuelassis/PDS-PrecoNoPosto.git',
#       'ssh_url': 'git@github.com:samuelassis/PDS-PrecoNoPosto.git',
#       'clone_url': 'https://github.com/samuelassis/PDS-PrecoNoPosto.git',
#       'svn_url': 'https://github.com/samuelassis/PDS-PrecoNoPosto',
#       'homepage': None,
#       'size': 241,
#       'stargazers_count': 1,
#       'watchers_count': 1,
#       'language': 'Kotlin',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 1,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/pulls/9'},
#      'html': {'href': 'https://github.com/samuelassis/PDS-PrecoNoPosto/pull/9'},
#      'issue': {'href': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/issues/9'},
#      'comments': {'href': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/issues/9/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/pulls/9/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/pulls/9/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/samuelassis/PDS-PrecoNoPosto/statuses/9af6027eea2d1dcf3e9185bb5df2dab6ebe25746'}},
#     'author_association': 'COLLABORATOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 5,
#     'additions': 1035,
#     'deletions': 237,
#     'changed_files': 27}},
#   'public': True,
#   'created_at': '2022-06-06T15:37:14Z'}]

# %% [markdown]
# # Gotta Catch 'Em All! Using the Pokemon API
#
# https://pokeapi.co/
#
# Nice place to start because there's no login details or credentials to fuss with
#
# For now, just want to explore grabbing the Types of different Pokemon.
#
# Useful documentation links:
# - Pokemon endpoint: https://pokeapi.co/docs/v2#pokemon
#     - `https://pokeapi.co/api/v2/pokemon/{id or name}/`
# - Type endpoint: https://pokeapi.co/docs/v2#types
#     - `https://pokeapi.co/api/v2/type/{id or name}/`

# %% [markdown]
# ### Start by exploring the response from the Pokemon endpoint
#
# Going to start with Charmander, pokemon #4, cause he's one of my favorites
#
# <img src="https://i.pinimg.com/originals/e7/0e/d0/e70ed0b54f9230c56c2e3bd2958d68a4.jpg" alt="adorable charmander found via pinterest" width=150>
#
# [Image Source](https://www.pinterest.com/pin/419045940312305352/)

# %%
# First, what endpoint url are we using?
base_poke_url = "https://pokeapi.co/api/v2/pokemon/"

# %%
# How does that need to adapt for charmander?
# char_url = f"{base_poke_url}charmander"
char_url = base_poke_url + "charmander"

# %%
char_url
# Out:
# 'https://pokeapi.co/api/v2/pokemon/charmander'

# %%
# Check the status code, will this work?
requests.get(char_url).status_code
# Out:
# 200

# %%
# Now let's actually get the response
char_resp = requests.get(char_url).json()

# %%
# Let's check out some details about the response
char_resp.keys()
# Out:
# dict_keys(['abilities', 'base_experience', 'forms', 'game_indices', 'height', 'held_items', 'id', 'is_default', 'location_area_encounters', 'moves', 'name', 'order', 'past_types', 'species', 'sprites', 'stats', 'types', 'weight'])

# %%
char_resp['id']
# Out:
# 4

# %%
char_resp['name']
# Out:
# 'charmander'

# %%
char_resp['types'][0]['type']['name']
# Out:
# 'fire'

# %%
bulba_resp = requests.get(base_poke_url + "1").json()
bulba_resp['types']
# Out:
# [{'slot': 1,
#   'type': {'name': 'grass', 'url': 'https://pokeapi.co/api/v2/type/12/'}},
#  {'slot': 2,
#   'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}}]

# %%
bulba_resp['types'][1]['type']['name']
# Out:
# 'poison'

# %% [markdown]
# #### Challenge!
#
# Let's write a function that, given a response from this API's pokemon endpoint, returns a list of the ID, name, primary type and secondary type for that pokemon.

# %%
def get_pokemon_details(poke_resp):
    '''
    inputs:
    poke_resp - expects json/dict
    
    outputs: 
    list of id, pokemon name, primary type and secondary type 
    '''
    poke_id = poke_resp['id']
    poke_name = poke_resp['name']
    primary_type = poke_resp['types'][0]['type']['name']
    
    if len(poke_resp['types']) > 1:
        secondary_type = poke_resp['types'][1]['type']['name']
    else: 
        secondary_type = 'None'
        
    return [poke_id, poke_name, primary_type, secondary_type]

# %%
# Let's test our function on the 3 original starter pokemon
original_starter_ids = list(range(1,10, 3))
print(original_starter_ids)
# Out:
# [1, 4, 7]

# %%
for poke_id in original_starter_ids:
    url = f"{base_poke_url}{poke_id}/"
    resp = requests.get(url).json()
    details = get_pokemon_details(resp)
    print(details)
# Out:
# [1, 'bulbasaur', 'grass', 'poison']
# [4, 'charmander', 'fire', 'None']
# [7, 'squirtle', 'water', 'None']

# %% [markdown]
# ### Moving to Pandas
#
# Let's get all of these details for all of the original 151 pokemon! And save them to a Pandas dataframe.

# %%
# Need to import pandas
import pandas as pd

# %%
# Let's go ahead and define what our columns will be
col_names = ['id', 'name', 'primary_type', 'secondary_type']

# %%
col_names
# Out:
# ['id', 'name', 'primary_type', 'secondary_type']

# %%
# Define a list of our 151 pokemon ids
original_151 = list(range(1,152))

# %% [markdown]
# So we're going to make 151 requests... don't want to overload the API endpoint! So let's use the time library to space out our requests.

# %%
import time

# %%
# Easiest way to do this will be to have a list of lists, then concat them all

# Define a blank list to capture all the pokemon details
row_list = []

# And then loop over our pokemon ids!
for poke_id in original_151:
    url = f"{base_poke_url}{poke_id}/"
    resp = requests.get(url).json()
    details = get_pokemon_details(resp)
    row_list.append(details)
    time.sleep(.5)
    
# Then, concat everything into one df
# Reference: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.append.html
poke_df = pd.concat([pd.DataFrame([i], columns = col_names) for i in row_list], ignore_index=True)

# %%
poke_df
# Out:
#       id        name primary_type secondary_type
# 0      1   bulbasaur        grass         poison
# 1      2     ivysaur        grass         poison
# 2      3    venusaur        grass         poison
# 3      4  charmander         fire           None
# 4      5  charmeleon         fire           None
# ..   ...         ...          ...            ...
# 146  147     dratini       dragon           None
# 147  148   dragonair       dragon           None
# 148  149   dragonite       dragon         flying
# 149  150      mewtwo      psychic           None
# 150  151         mew      psychic           None
#
# [151 rows x 4 columns]

# %%
# visualize it!
import matplotlib.pyplot as plt

primary_type_count = poke_df.groupby('primary_type').count()['id'].sort_values(ascending=False)

plt.figure(figsize=(10,8))
plt.bar(primary_type_count.index, primary_type_count)

plt.title("Counts of Pokemon Primary Types")
plt.ylabel("Number of Pokemon")
plt.xlabel("Primary Type")
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ![monty python gif - and now for something completely different, from giphy](https://media.giphy.com/media/xznyPebL28X5u/giphy.gif)

# %% [markdown]
# # Movie Time!
#
# Let's practice with an API that actually requires some authorization, in the form of an API Key!
#
# https://www.themoviedb.org/documentation/api

# %% [markdown]
# # **NEVER EVER PUT YOUR API KEY ON GITHUB**
#
# Either create a json file with API keys in a different directory, or create a python file with the key saved as a variable that you can call. (There are even more options than that, but these are two easily-accessible ones)

# %%
# Option 1: use a json file saved to some other folder outside your Git repo
# You can make a secrets folder on your ~ directory!
# In a new terminal window, create a file called api.json and save the path to that file

# Need to import json to do this
import json

# Quick helper function to open the json
def get_keys(path):
    with open(path) as f:
        return json.load(f)

# Using the function to open and load all keys in that file 
api_keys = get_keys("/Users/lberlin/secrets/api.json")

# Setting the first (and only) value as a variable
tmdb_key_1 = api_keys['tmdb_key']

# %%
# Option 2: use a python file that's been added to your .gitignore

# In a new terminal window, create a file called keys.py in this repo
# Save the api key as tmdb_api_key = "[key]"

from keys import tmdb_api_key as tmdb_key_2

# tmdb_key_2 = tmdb_api_key

# Then let's edit our .gitignore file together

# %% [markdown]
# Just as important! You may want to call the variable you've set to check that the API key is rendering correctly - but **be sure to clear the output of that cell** or else the output will show your key! And then if you push to GitHub it'll push that output to the internet which defeats the whole point of saving your key elsewhere!

# %% [markdown]
# ### And now, accessing movie data
#
# Documentation: https://developers.themoviedb.org/3

# %%
# Default URL given as an example... let's see what it is!
test_url = f"https://api.themoviedb.org/3/movie/550?api_key={tmdb_key_2}"

# %%
test_resp = requests.get(test_url).json()

# %%
test_resp.keys()
# Out:
# dict_keys(['adult', 'backdrop_path', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id', 'imdb_id', 'original_language', 'original_title', 'overview', 'popularity', 'poster_path', 'production_companies', 'production_countries', 'release_date', 'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title', 'video', 'vote_average', 'vote_count'])

# %%
# Find similar movies to the previous id
fight_club_id = 550
similar_url = f"https://api.themoviedb.org/3/movie/{fight_club_id}/similar?api_key={tmdb_key_1}"
similar_resp = requests.get(similar_url).json()

# %%
similar_resp.keys()
# Out:
# dict_keys(['page', 'results', 'total_pages', 'total_results'])

# %%
# How many similar movies did it find?
similar_resp['total_results']
# Out:
# 10000

# %%
# but is that the length of these results?
len(similar_resp['results'])
# Out:
# 20

# %%
test_id = similar_resp['results'][0]['id']

# %%
new_test_url = f"https://api.themoviedb.org/3/movie/{test_id}?api_key={tmdb_key_2}"

# %%
test_resp = requests.get(new_test_url).json()
test_resp
# Out:
# {'adult': False,
#  'backdrop_path': '/qjGrUmKW78MCFG8PTLDBp67S27p.jpg',
#  'belongs_to_collection': {'id': 925155,
#   'name': 'Demon Slayer',
#   'poster_path': '/q8wplgnax24RuOlUnDBT0hIZ2tr.jpg',
#   'backdrop_path': None},
#  'budget': 15800000,
#  'genres': [{'id': 16, 'name': 'Animation'},
#   {'id': 28, 'name': 'Action'},
#   {'id': 12, 'name': 'Adventure'},
#   {'id': 14, 'name': 'Fantasy'}],
#  'homepage': 'https://demonslayer-anime.com',
#  'id': 635302,
#  'imdb_id': 'tt11032374',
#  'original_language': 'ja',
#  'original_title': '劇場版「鬼滅の刃」無限列車編',
#  'overview': "Tanjirō Kamado, joined with Inosuke Hashibira, a boy raised by boars who wears a boar's head, and Zenitsu Agatsuma, a scared boy who reveals his true power when he sleeps, boards the Infinity Train on a new mission with the Fire Hashira, Kyōjurō Rengoku, to defeat a demon who has been tormenting the people and killing the demon slayers who oppose it!",
#  'popularity': 898.084,
#  'poster_path': '/h8Rb9gBr48ODIwYUttZNYeMWeUU.jpg',
#  'production_companies': [{'id': 5887,
#    'logo_path': '/m6FEqz8rQECnmfjEwjNhNAlmhCJ.png',
#    'name': 'ufotable',
#    'origin_country': 'JP'},
#   {'id': 2883,
#    'logo_path': '/rDYExnBV61jGQnkhVVrPN4Yl7O1.png',
#    'name': 'Aniplex',
#    'origin_country': 'JP'},
#   {'id': 2918,
#    'logo_path': '/gyEWUBWwqrm3H5T2hkERD9LxpOq.png',
#    'name': 'Shueisha',
#    'origin_country': 'JP'},
#   {'id': 91520,
#    'logo_path': '/wdcFLdFVOPEm3uEp6Hb9OXgi5Zd.png',
#    'name': 'STUDIO MAUSU',
#    'origin_country': 'JP'}],
#  'production_countries': [{'iso_3166_1': 'JP', 'name': 'Japan'}],
#  'release_date': '2020-10-16',
#  'revenue': 503063688,
#  'runtime': 117,
#  'spoken_languages': [{'english_name': 'Japanese',
#    'iso_639_1': 'ja',
#    'name': '日本語'}],
#  'status': 'Released',
#  'tagline': 'With your blade, bring an end to the nightmare.',
#  'title': 'Demon Slayer -Kimetsu no Yaiba- The Movie: Mugen Train',
#  'video': False,
#  'vote_average': 8.4,
#  'vote_count': 2448}

# %%
# what's in here?
for res in similar_resp['results']:
    print(res['title'])
# Out:
# Demon Slayer -Kimetsu no Yaiba- The Movie: Mugen Train
# The Mauritanian
# Cheaper by the Dozen
# The Power of the Dog
# Through My Window
# The Kissing Booth 3
# The Mad Women's Ball
# The Yin-Yang Master: Dream of Eternity
# Yes, No, or Maybe Half?
# Girls from Dubai
# Against the Ice
# Love Like the Falling Petals
# American Badger
# Mother/Android
# After We Fell
# Sword Art Online the Movie -Progressive- Aria of a Starless Night
# Cry Macho
# The Colony
# The Tiger Rising
# No One Gets Out Alive

# %% [markdown]
# ## Level Up: Another Way to Deal with APIs
#
# Check out [Postman](https://www.getpostman.com/).

# %% [markdown]
# ## Extra Credit: Further Practice
#
# There are many ways to access data through APIs! [Sodapy](https://github.com/xmunoz/sodapy) is the Python client for the Socrata Open Data API.

# %%
# Install before running 
# !pip install sodapy

# %% [markdown]
# #### Tokenize yourself!
#
# https://dev.socrata.com/foundry/data.cityofnewyork.us/fhrw-4uyv
#
# Scroll down and click to sign up for an app token! No credit cards required!

# %%
token = '' # paste your token here 

import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofnewyork.us", token)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofnewyork.us,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("fhrw-4uyv", incident_zip = '11004', limit=1000)

# %%
type(results)

# %%
len(results)

# %%
results[0]

# %%
df_soda = pd.DataFrame(results)

print(len(df_soda))
print(df_soda.columns)
df_soda.head()

# %% [markdown]
# ## Even Further Practice
#
# https://github.com/toddmotto/public-apis
#
# Find a buddy, find a free api, get a key, and do a GET. Try to transform the response into a dataframe.
